# %%
x=int(input('Enter x:'))
y=int (input('Enter y: '))
if y>x:
    print('Y is greater than x')
elif x==y:
    print ('x is equal to y')
else:
    print ('x is greater than y')
# Out:
# Enter x:10
# Enter y: 10
# x is equal to y

# %%
Dept = 'Data Science'
if Dept=='Data Science':
    print ('You have a great future!')
else:
    print('Worried!')
print ('Learn Data Science from study Mart')
# Out:
# You have a great future!
# Learn Data Science from study Mart

# %%
num=float (input('enter any number: '))
if num%2==0:
    if num%5==0:
        print(num,'Divisible by 2 and 5')
    else :
        print ('No')
else:
    print('No')
# Out:
# enter any number: 60
# 60.0 Divisible by 2 and 5

# %%
from IPython.display import Image
Image('Electricity.jpg')

# %%
amount=0
net_unit = float(input('Enter your limit value'))
if net_unit<=100:
    amount=0
elif net_unit>100 and net_unit<=200:
    amount = net_unit*5
else:
    amount=500+(net_unit-200)*10
print('Bill is ',amount)
# Out:
# Enter your limit value350
# Bill is  2000.0
